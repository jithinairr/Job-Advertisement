# %% [markdown]
# # Assignment 2: Milestone I Natural Language Processing
# ## Task 1. Basic Text Pre-processing
# #### Student Name: Padinjarekolath Jithin Nair
# #### Student ID: s3952043
#
# Date: 20/09/2023
#
# Version: 1.0
#
# Environment: Python 3 and Jupyter notebook
#
# Libraries used: please include all the libraries you used in your assignment, e.g.,:
# * pandas
# * re
# * os
# * nltk
#
# ## Introduction
#
# Task 1 involves preparing job advertisement descriptions for further analysis. We perform essential text pre-processing steps, including tokenization, lowercasing, stopword removal, and more. The result is a cleaned dataset with a vocabulary that sets the foundation for subsequent tasks.

# %% [markdown]
# ## Importing libraries

# %%
# Code to import libraries as you need in this assessment
import pandas as pd
import re
import os
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist

# %% [markdown]
# ### 1.1 Examining and loading data
# - Examine the data folder, including the categories and job advertisment txt documents, etc. Explain your findings here, e.g., number of folders and format of txt files, etc.
# - Load the data into proper data structures and get it ready for processing.
# - Extract webIndex and description into proper data structures.

# %%
def load_stopwords(stopwords_file):
    with open(stopwords_file, 'r') as f:
        stopwords_list = f.read().splitlines()
    return set(stopwords_list)

# Load stopwords
stopwords_set = load_stopwords("stopwords_en.txt")

# Define the path to the "data" folder where job category folders are located
data_folder = "data"

num_categories = 0
category_file_counts = {}

# Loop through each job category folder
for category_folder in os.listdir(data_folder):
    category_path = os.path.join(data_folder, category_folder)

    # Check if it's a directory (job category)
    if os.path.isdir(category_path):
        num_categories += 1

        # Count the number of files in the category folder
        file_count = len([file for file in os.listdir(category_path) if file.endswith(".txt")])
        category_file_counts[category_folder] = file_count

# Print the number of job categories
print(f"Number of Job Categories: {num_categories}")

# Print the number of files in each category
for category, file_count in category_file_counts.items():
    print(f"Category: {category}, Number of Files: {file_count}")
# Out:
# Number of Job Categories: 4
# Category: Sales, Number of Files: 156
# Category: Accounting_Finance, Number of Files: 191
# Category: Healthcare_Nursing, Number of Files: 198
# Category: Engineering, Number of Files: 231

# %% [markdown]
# There are 4 folders namely Sales, Accounting_Finance, Healthcare_Nursing, and Engineering with its respective file count 156, 191, 198, and 231.

# %%
# Initialize a list to store extracted information from all files
job_info_list = []

# Loop through each job category folder
job_folders = ["Accounting_Finance", "Engineering", "Healthcare_Nursing", "Sales"]
for category_name in job_folders:
    category_path = os.path.join(data_folder, category_name)

    # Loop through each job advertisement file in the category folder
    for file_name in os.listdir(category_path):
        if file_name.startswith("Job_") and file_name.endswith(".txt"):
            file_path = os.path.join(category_path, file_name)

            # Initialize variables to store extracted values
            title = None
            webindex = None
            company = None
            description = None

            # Read the job advertisement text from the file
            with open(file_path, 'r', encoding='utf-8') as file:
                file_content = file.read()

            # Split the file content into lines
            lines = file_content.strip().split('\n')

            # Iterate through lines to extract information
            for line in lines:
                key, value = line.strip().split(': ', 1)
                if key == 'Title':
                    title = value
                elif key == 'Webindex':
                    webindex = value
                elif key == 'Company':
                    company = value
                elif key == 'Description':
                    description = value

            # Store extracted information in a dictionary
            job_info = {
                'Title': title,
                'Webindex': webindex,
                'Company': company,
                'Description': description
            }

            # Append the dictionary to the list
            job_info_list.append(job_info)

# Print the extracted information for the first job advertisement
print(job_info_list[0])
# Out:
# {'Title': 'Commercial Insurance Underwriter', 'Webindex': '69092773', 'Company': 'Bond Search Selection Ltd', 'Description': 'Our client is a leading Insurer based in Belfast. As part of their continued expansion an opportunity has arisen for an enthusiastic, experienced individual to join the Commercial Underwriting Team in Belfast. Job Specification:  Liaise with the broker network in relation to quotations for Liability, Property Commercial combined risks  Complying with all regulatory and internal systems controls.  Proactively resolving enquiries from the Agency network and Operations Team.  Providing expert technical advice and guidance to customers.  Analysing, underwriting and processing individual risks, including more complex Risks.  Providing coaching and guidance to other members of the Team.  Supporting achievement of Regional growth and loss ratio targets, including liaison with the Operations Team and field visits when required. Personal Specification The successful candidate will be required to demonstrate:  Appropriate experience within a Commercial Underwriting environment.  A commitment to good customer care.  Excellent organisation and communication skills.  The ability to influence and implement change.  Initiative to identify and act upon process and service improvements.  Strong teamworking skills.  A proactive approach to the acquisition of business.  A positive can do attitude.  A sound technical knowledge.  The drive to meet challenging deadlines and achieve quality service standards. Essential Criteria A minimum of 5 years experience of Commercial Insurance Underwriting. Remuneration will be in the region of ****  **** and will include a market leading benefits package. To be considered please forward a CV in strictest confidence via the online application process. We are aware of the need for complete discretion when recruiting this level of position therefore your details will not be passed to any client until you have been made aware of the employer and have instructed us to proceed. To view our full range of similar vacancies or to register for jobs alerts via Twitter, please visit our website at www.bondselection.com As a corporate member of the Recruitment and Employment Confederation (REC), Bond Search Selection operates as both an Employment Agency and Employment Business. We adhere to all relevant legislation and offer services regardless of age, race, sex, disability or religious belief.'}

# %% [markdown]
# The format of the file contains Title, Webindex, Company, and Description. I have displayed just the first value of the list as there are 776 rows.

# %%
# Convert the list to a dataframe for ease of access
job_info = pd.DataFrame(job_info_list)
job_info
# Out:
#                                                  Title  Webindex  \
# 0                     Commercial Insurance Underwriter  69092773
# 1                            Regulatory Policy Manager  71674555
# 2                               PA to Managing Partner  70758175
# 3                       Fixed Income Portfolio Analyst  69564390
# 4                           Commercial Finance Analyst  70255258
# ..                                                 ...       ...
# 771      European Account Manager (German and English)  66399629
# 772  Graduate Sales Executive, Construction Product...  68702817
# 773  International Sales Account Manager  German Ma...  66935937
# 774                     Rail Signal Design Team Leader  71812011
# 775                  Eco deal Surveyor / Sales Advisor  69768475
#
#                              Company  \
# 0          Bond Search Selection Ltd
# 1    Michael Page Financial Services
# 2                       Wells Tobias
# 3                    Mason Blake Ltd
# 4                Axon Resourcing Ltd
# ..                               ...
# 771               Positive Selection
# 772   Aaron Wallis Sales Recruitment
# 773          INTERACTION RECRUITMENT
# 774                    UKStaffsearch
# 775                   ENERGYADVICEUK
#
#                                            Description
# 0    Our client is a leading Insurer based in Belfa...
# 1    As a Regulatory Policy Manager at a leading Fi...
# 2    A brand new position has arisen within a highl...
# 3    This is a newly created position will involve ...
# 4    A newly created role for a commercial finance ...
# ..                                                 ...
# 771  Our client is in urgent need of a candidate wi...
# 772  Graduate Sales Executive, Construction Product...
# 773  INTERNATIONAL SALES ACCOUNT MANAGER  managing ...
# 774  We are currently looking for Rail Signal Desig...
# 775  EXPERIENCED CAVITY WALL AND LOFT SURVEYORS NEE...
#
# [776 rows x 4 columns]

# %%
job_info.dtypes
# Out:
# Title          object
# Webindex       object
# Company        object
# Description    object
# dtype: object

# %%
# Converting WEbindex to appropriate datatype
job_info['Webindex'] = job_info['Webindex'].astype(int)

# %%
job_info.dtypes
# Out:
# Title          object
# Webindex        int64
# Company        object
# Description    object
# dtype: object

# %%
df = job_info[['Webindex', 'Description']]
df
# Out:
#      Webindex                                        Description
# 0    69092773  Our client is a leading Insurer based in Belfa...
# 1    71674555  As a Regulatory Policy Manager at a leading Fi...
# 2    70758175  A brand new position has arisen within a highl...
# 3    69564390  This is a newly created position will involve ...
# 4    70255258  A newly created role for a commercial finance ...
# ..        ...                                                ...
# 771  66399629  Our client is in urgent need of a candidate wi...
# 772  68702817  Graduate Sales Executive, Construction Product...
# 773  66935937  INTERNATIONAL SALES ACCOUNT MANAGER  managing ...
# 774  71812011  We are currently looking for Rail Signal Desig...
# 775  69768475  EXPERIENCED CAVITY WALL AND LOFT SURVEYORS NEE...
#
# [776 rows x 2 columns]

# %% [markdown]
# ### 1.2 Pre-processing data
# Perform the required text pre-processing steps.

# %%
# Define a regular expression pattern for tokenization
pattern = r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?"
tokenizer = RegexpTokenizer(pattern)

# Initialize lists for preprocessed descriptions and tokenized descriptions
preprocessed_descriptions = []
tokenized_descriptions = []

# Initialize a list to store all words in the document collection
all_words = []

# Initialize a dictionary to keep track of word frequencies
word_freq = FreqDist()

# Initialize a WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Loop through each description
for webindex, description in zip(df['Webindex'], df['Description']):
    # Tokenize using the provided regular expression
    tokens = tokenizer.tokenize(description)
    
    # Convert tokens to lowercase, filter out short words, and remove stopwords
    filtered_tokens = [token.lower() for token in tokens if len(token) > 2 and token.lower() not in stopwords_set]
    
    # Update the list of all words and word frequencies
    all_words.extend(filtered_tokens)
    word_freq.update(filtered_tokens)
    
    # Perform lemmatization
    lem_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
    for original_word, lemmatized_word in zip(filtered_tokens, lem_tokens):
        if lemmatized_word != original_word and lem_tokens.count(lemmatized_word) == 1:
            print(f"Original: {original_word}, Lemmatized: {lemmatized_word}")
    
    # Append the preprocessed description and tokenized description to their respective lists
    preprocessed_description = " ".join(lem_tokens)
    preprocessed_descriptions.append((webindex, preprocessed_description))
    tokenized_descriptions.append(lem_tokens)

# Create a set of words that appear more than once
words_appearing_more_than_once = set(word for word, freq in word_freq.items() if freq > 1)

# Remove words that appear only once in the document collection
preprocessed_descriptions = [(webindex, " ".join([token for token in description.split() 
                                                  if token in words_appearing_more_than_once])) 
                             for webindex, description in preprocessed_descriptions]

# Remove the top 50 most frequent words based on document frequency
sorted_word_freq = word_freq.most_common()
most_common_words = set([word for word, _ in sorted_word_freq[:50]])

preprocessed_descriptions = [(webindex, " ".join([token for token in description.split() 
                                                  if token not in most_common_words])) 
                             for webindex, description in preprocessed_descriptions]

# Save preprocessed job advertisements to a CSV file
preprocessed_df = pd.DataFrame(preprocessed_descriptions)
preprocessed_df.to_csv("preprocessed_ads.csv", index=False, header=False, encoding='utf-8')
# Out:
# Original: quotations, Lemmatized: quotation
# Original: systems, Lemmatized: system
# Original: controls, Lemmatized: control
# Original: enquiries, Lemmatized: enquiry
# Original: targets, Lemmatized: target
# Original: improvements, Lemmatized: improvement
# Original: deadlines, Lemmatized: deadline
# Original: standards, Lemmatized: standard
# Original: criteria, Lemmatized: criterion
# Original: years, Lemmatized: year
# Original: benefits, Lemmatized: benefit
# Original: details, Lemmatized: detail
# Original: vacancies, Lemmatized: vacancy
# Original: alerts, Lemmatized: alert
# Original: papers, Lemmatized: paper
# Original: impacts, Lemmatized: impact
# Original: decisions, Lemmatized: decision
# Original: requirements, Lemmatized: requirement
# Original: regions, Lemmatized: region
# Original: lines, Lemmatized: line
# Original: findings, Lemmatized: finding
# Original: conclusions, Lemmatized: conclusion
# Original: timelines, Lemmatized: timeline
# Original: individuals, Lemmatized: individual
# Original: pressures, Lemmatized: pressure
# Original: candidates, Lemmatized: candidate
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: equivalents, Lemmatized: equivalent
# Original: analysts, Lemmatized: analyst
# Original: diaries, Lemmatized: diary
# Original: meetings, Lemmatized: meeting
# Original: arrangements, Lemmatized: arrangement
# Original: duties, Lemmatized: duty
# Original: expenses, Lemmatized: expense
# Original: spreadsheets, Lemmatized: spreadsheet
# Original: queries, Lemmatized: query
# Original: issues, Lemmatized: issue
# Original: couriers, Lemmatized: courier
# Original: visitors, Lemmatized: visitor
# Original: skills, Lemmatized: skill
# Original: languages, Lemmatized: language
# Original: managers, Lemmatized: manager
# Original: traders, Lemmatized: trader
# Original: strategies, Lemmatized: strategy
# Original: movements, Lemmatized: movement
# Original: skills, Lemmatized: skill
# Original: qualifications, Lemmatized: qualification
# Original: acts, Lemmatized: act
# Original: workers, Lemmatized: worker
# Original: opportunities, Lemmatized: opportunity
# Original: welcomes, Lemmatized: welcome
# Original: applications, Lemmatized: application
# Original: sales, Lemmatized: sale
# Original: anomalies, Lemmatized: anomaly
# Original: variances, Lemmatized: variance
# Original: stakeholders, Lemmatized: stakeholder
# Original: retentions, Lemmatized: retention
# Original: hours, Lemmatized: hour
# Original: focuses, Lemmatized: focus
# Original: payments, Lemmatized: payment
# Original: creditors, Lemmatized: creditor
# Original: standards, Lemmatized: standard
# Original: meets, Lemmatized: meet
# Original: procedures, Lemmatized: procedure
# Original: controls, Lemmatized: control
# Original: issues, Lemmatized: issue
# Original: relationships, Lemmatized: relationship
# Original: agencies, Lemmatized: agency
# Original: fos, Lemmatized: fo
# Original: citizens, Lemmatized: citizen
# Original: essentials, Lemmatized: essential
# Original: months, Lemmatized: month
# Original: qualifications, Lemmatized: qualification
# Original: maths, Lemmatized: math
# Original: clients, Lemmatized: client
# Original: benefits, Lemmatized: benefit
# Original: allowances, Lemmatized: allowance
# Original: bonuses, Lemmatized: bonus
# Original: specifics, Lemmatized: specific
# Original: colleagues, Lemmatized: colleague
# Original: files, Lemmatized: file
# Original: guidelines, Lemmatized: guideline
# Original: options, Lemmatized: option
# Original: standards, Lemmatized: standard
# Original: values, Lemmatized: value
# Original: suppliers, Lemmatized: supplier
# Original: offers, Lemmatized: offer
# Original: possess, Lemmatized: posse
# Original: results, Lemmatized: result
# Original: passes, Lemmatized: pass
# Original: hours, Lemmatized: hour
# Original: weekends, Lemmatized: weekend
# Original: outputs, Lemmatized: output
# Original: relationships, Lemmatized: relationship
# Original: areas, Lemmatized: area
# Original: templates, Lemmatized: template
# Original: tolerances, Lemmatized: tolerance
# Original: implications, Lemmatized: implication
# Original: products, Lemmatized: product
# Original: executives, Lemmatized: executive
# Original: requirements, Lemmatized: requirement
# Original: scenarios, Lemmatized: scenario
# Original: tests, Lemmatized: test
# Original: drivers, Lemmatized: driver
# Original: trails, Lemmatized: trail
# Original: reports, Lemmatized: report
# Original: systems, Lemmatized: system
# Original: responsibilities, Lemmatized: responsibility
# Original: deposits, Lemmatized: deposit
# Original: cls, Lemmatized: cl
# Original: relationships, Lemmatized: relationship
# Original: dealers, Lemmatized: dealer
# Original: discrepancies, Lemmatized: discrepancy
# Original: differences, Lemmatized: difference
# Original: systems, Lemmatized: system
# Original: members, Lemmatized: member
# Original: controls, Lemmatized: control
# Original: tasks, Lemmatized: task
# Original: projects, Lemmatized: project
# Original: agents, Lemmatized: agent
# Original: clients, Lemmatized: client
# Original: customers, Lemmatized: customer
# Original: transfers, Lemmatized: transfer
# Original: leavers, Lemmatized: leaver
# Original: types, Lemmatized: type
# Original: queries, Lemmatized: query
# Original: quotations, Lemmatized: quotation
# Original: settlements, Lemmatized: settlement
# Original: calculations, Lemmatized: calculation
# Original: duties, Lemmatized: duty
# Original: days, Lemmatized: day
# Original: benefits, Lemmatized: benefit
# Original: years, Lemmatized: year
# Original: industries, Lemmatized: industry
# Original: additions, Lemmatized: addition
# Original: areas, Lemmatized: area
# Original: objectives, Lemmatized: objective
# Original: duties, Lemmatized: duty
# Original: operations, Lemmatized: operation
# Original: bids, Lemmatized: bid
# Original: tenders, Lemmatized: tender
# Original: banks, Lemmatized: bank
# Original: audits, Lemmatized: audit
# Original: associates, Lemmatized: associate
# Original: accountabilities, Lemmatized: accountability
# Original: areas, Lemmatized: area
# Original: directors, Lemmatized: director
# Original: policies, Lemmatized: policy
# Original: limits, Lemmatized: limit
# Original: institutions, Lemmatized: institution
# Original: systems, Lemmatized: system
# Original: skills, Lemmatized: skill
# Original: assignments, Lemmatized: assignment
# Original: standards, Lemmatized: standard
# Original: stakeholders, Lemmatized: stakeholder
# Original: mechanisms, Lemmatized: mechanism
# Original: services, Lemmatized: service
# Original: areas, Lemmatized: area
# Original: derivatives, Lemmatized: derivative
# Original: skills, Lemmatized: skill
# Original: acts, Lemmatized: act
# Original: workers, Lemmatized: worker
# Original: disclaimers, Lemmatized: disclaimer
# Original: seeks, Lemmatized: seek
# Original: queries, Lemmatized: query
# Original: referrals, Lemmatized: referral
# Original: enquiries, Lemmatized: enquiry
# Original: channels, Lemmatized: channel
# Original: opportunities, Lemmatized: opportunity
# Original: colleges, Lemmatized: college
# Original: responsibilities, Lemmatized: responsibility
# Original: regulations, Lemmatized: regulation
# Original: notes, Lemmatized: note
# Original: creditors, Lemmatized: creditor
# Original: restrictions, Lemmatized: restriction
# Original: details, Lemmatized: detail
# Original: receipts, Lemmatized: receipt
# Original: claims, Lemmatized: claim
# Original: councils, Lemmatized: council
# Original: reports, Lemmatized: report
# Original: salaries, Lemmatized: salary
# Original: certifications, Lemmatized: certification
# Original: lasts, Lemmatized: last
# Original: covers, Lemmatized: cover
# Original: hours, Lemmatized: hour
# Original: aspects, Lemmatized: aspect
# Original: skills, Lemmatized: skill
# Original: rooms, Lemmatized: room
# Original: assessments, Lemmatized: assessment
# Original: assignments, Lemmatized: assignment
# Original: examinations, Lemmatized: examination
# Original: processes, Lemmatized: process
# Original: relations, Lemmatized: relation
# Original: duties, Lemmatized: duty
# Original: reviews, Lemmatized: review
# Original: actions, Lemmatized: action
# Original: procedures, Lemmatized: procedure
# Original: stakeholders, Lemmatized: stakeholder
# Original: requirements, Lemmatized: requirement
# Original: recommendations, Lemmatized: recommendation
# Original: media, Lemmatized: medium
# Original: resources, Lemmatized: resource
# Original: participants, Lemmatized: participant
# Original: leaders, Lemmatized: leader
# Original: levels, Lemmatized: level
# Original: aspects, Lemmatized: aspect
# Original: employees, Lemmatized: employee
# Original: hands, Lemmatized: hand
# Original: economies, Lemmatized: economy
# Original: benefits, Lemmatized: benefit
# Original: years, Lemmatized: year
# Original: rules, Lemmatized: rule
# Original: requirements, Lemmatized: requirement
# Original: controls, Lemmatized: control
# Original: reviews, Lemmatized: review
# Original: systems, Lemmatized: system
# Original: processes, Lemmatized: process
# Original: strategies, Lemmatized: strategy
# Original: disciplines, Lemmatized: discipline
# Original: situations, Lemmatized: situation
# Original: industries, Lemmatized: industry
# Original: capabilities, Lemmatized: capability
# Original: contacts, Lemmatized: contact
# Original: duties, Lemmatized: duty
# Original: proposals, Lemmatized: proposal
# Original: duties, Lemmatized: duty
# Original: areas, Lemmatized: area
# Original: objectives, Lemmatized: objective
# Original: criteria, Lemmatized: criterion
# Original: matters, Lemmatized: matter
# Original: threats, Lemmatized: threat
# Original: services, Lemmatized: service
# Original: applicants, Lemmatized: applicant
# Original: controls, Lemmatized: control
# Original: audits, Lemmatized: audit
# Original: terms, Lemmatized: term
# Original: requirements, Lemmatized: requirement
# Original: qualifications, Lemmatized: qualification
# Original: benefits, Lemmatized: benefit
# Original: areas, Lemmatized: area
# Original: developments, Lemmatized: development
# Original: assess, Lemmatized: ass
# Original: processes, Lemmatized: process
# Original: systems, Lemmatized: system
# Original: rules, Lemmatized: rule
# Original: improvements, Lemmatized: improvement
# Original: customers, Lemmatized: customer
# Original: actions, Lemmatized: action
# Original: reports, Lemmatized: report
# Original: matters, Lemmatized: matter
# Original: owners, Lemmatized: owner
# Original: approvals, Lemmatized: approval
# Original: returns, Lemmatized: return
# Original: members, Lemmatized: member
# Original: skills, Lemmatized: skill
# Original: responsibilities, Lemmatized: responsibility
# Original: reviews, Lemmatized: review
# Original: payments, Lemmatized: payment
# Original: queries, Lemmatized: query
# Original: sales, Lemmatized: sale
# Original: duties, Lemmatized: duty
# Original: assess, Lemmatized: ass
# Original: sources, Lemmatized: source
# Original: decisions, Lemmatized: decision
# Original: letters, Lemmatized: letter
# Original: solutions, Lemmatized: solution
# Original: emails, Lemmatized: email
# Original: faxes, Lemmatized: fax
# Original: customers, Lemmatized: customer
# Original: intermediaries, Lemmatized: intermediary
# Original: skills, Lemmatized: skill
# Original: possess, Lemmatized: posse
# Original: hours, Lemmatized: hour
# Original: responsibilities, Lemmatized: responsibility
# Original: limits, Lemmatized: limit
# Original: balances, Lemmatized: balance
# Original: letters, Lemmatized: letter
# Original: skills, Lemmatized: skill
# Original: candidates, Lemmatized: candidate
# Original: benefits, Lemmatized: benefit
# Original: offers, Lemmatized: offer
# Original: conditions, Lemmatized: condition
# Original: individuals, Lemmatized: individual
# Original: relationships, Lemmatized: relationship
# Original: clients, Lemmatized: client
# Original: services, Lemmatized: service
# Original: advisers, Lemmatized: adviser
# Original: queries, Lemmatized: query
# Original: questions, Lemmatized: question
# Original: individuals, Lemmatized: individual
# Original: schemes, Lemmatized: scheme
# Original: administrators, Lemmatized: administrator
# Original: duties, Lemmatized: duty
# Original: skills, Lemmatized: skill
# Original: goals, Lemmatized: goal
# Original: forecasts, Lemmatized: forecast
# Original: targets, Lemmatized: target
# Original: systems, Lemmatized: system
# Original: disciplines, Lemmatized: discipline
# Original: relationships, Lemmatized: relationship
# Original: skills, Lemmatized: skill
# Original: benefits, Lemmatized: benefit
# Original: responsibilities, Lemmatized: responsibility
# Original: files, Lemmatized: file
# Original: letters, Lemmatized: letter
# Original: issues, Lemmatized: issue
# Original: requirements, Lemmatized: requirement
# Original: queries, Lemmatized: query
# Original: colleagues, Lemmatized: colleague
# Original: providers, Lemmatized: provider
# Original: meetings, Lemmatized: meeting
# Original: minutes, Lemmatized: minute
# Original: goals, Lemmatized: goal
# Original: objectives, Lemmatized: objective
# Original: constraints, Lemmatized: constraint
# Original: plans, Lemmatized: plan
# Original: skills, Lemmatized: skill
# Original: trends, Lemmatized: trend
# Original: windows, Lemmatized: window
# Original: packages, Lemmatized: package
# Original: procedures, Lemmatized: procedure
# Original: categories, Lemmatized: category
# Original: standards, Lemmatized: standard
# Original: disciplines, Lemmatized: discipline
# Original: investments, Lemmatized: investment
# Original: pensions, Lemmatized: pension
# Original: services, Lemmatized: service
# Original: areas, Lemmatized: area
# Original: transactions, Lemmatized: transaction
# Original: activities, Lemmatized: activity
# Original: discuss, Lemmatized: discus
# Original: hours, Lemmatized: hour
# Original: vacancies, Lemmatized: vacancy
# Original: sources, Lemmatized: source
# Original: hundreds, Lemmatized: hundred
# Original: firms, Lemmatized: firm
# Original: members, Lemmatized: member
# Original: thousands, Lemmatized: thousand
# Original: relations, Lemmatized: relation
# Original: aspects, Lemmatized: aspect
# Original: auditors, Lemmatized: auditor
# Original: owners, Lemmatized: owner
# Original: awards, Lemmatized: award
# Original: schemes, Lemmatized: scheme
# Original: items, Lemmatized: item
# Original: forecasts, Lemmatized: forecast
# Original: colleagues, Lemmatized: colleague
# Original: systems, Lemmatized: system
# Original: periods, Lemmatized: period
# Original: requirements, Lemmatized: requirement
# Original: standards, Lemmatized: standard
# Original: dynamics, Lemmatized: dynamic
# Original: requirements, Lemmatized: requirement
# Original: skills, Lemmatized: skill
# Original: schemes, Lemmatized: scheme
# Original: services, Lemmatized: service
# Original: benefits, Lemmatized: benefit
# Original: fellows, Lemmatized: fellow
# Original: residents, Lemmatized: resident
# Original: boroughs, Lemmatized: borough
# Original: terms, Lemmatized: term
# Original: conditions, Lemmatized: condition
# Original: watts, Lemmatized: watt
# Original: interviews, Lemmatized: interview
# Original: reasons, Lemmatized: reason
# Original: sales, Lemmatized: sale
# Original: accounts, Lemmatized: account
# Original: targets, Lemmatized: target
# Original: initiatives, Lemmatized: initiative
# Original: products, Lemmatized: product
# Original: rates, Lemmatized: rate
# Original: insurers, Lemmatized: insurer
# Original: risks, Lemmatized: risk
# Original: qualifications, Lemmatized: qualification
# Original: benefits, Lemmatized: benefit
# Original: discuss, Lemmatized: discus
# Original: hours, Lemmatized: hour
# Original: vacancies, Lemmatized: vacancy
# Original: sources, Lemmatized: source
# Original: years, Lemmatized: year
# Original: services, Lemmatized: service
# Original: accountants, Lemmatized: accountant
# Original: opportunities, Lemmatized: opportunity
# Original: applicants, Lemmatized: applicant
# Original: days, Lemmatized: day
# Original: earners, Lemmatized: earner
# Original: areas, Lemmatized: area
# Original: demands, Lemmatized: demand
# Original: skills, Lemmatized: skill
# Original: individuals, Lemmatized: individual
# Original: days, Lemmatized: day
# Original: assessments, Lemmatized: assessment
# Original: registers, Lemmatized: register
# Original: controls, Lemmatized: control
# Original: individuals, Lemmatized: individual
# Original: groups, Lemmatized: group
# Original: accounts, Lemmatized: account
# Original: duties, Lemmatized: duty
# Original: aspects, Lemmatized: aspect
# Original: invoices, Lemmatized: invoice
# Original: payments, Lemmatized: payment
# Original: queries, Lemmatized: query
# Original: procedures, Lemmatized: procedure
# Original: supervisors, Lemmatized: supervisor
# Original: operations, Lemmatized: operation
# Original: reconciliations, Lemmatized: reconciliation
# Original: debits, Lemmatized: debit
# Original: credits, Lemmatized: credit
# Original: businesses, Lemmatized: business
# Original: solutions, Lemmatized: solution
# Original: branches, Lemmatized: branch
# Original: locations, Lemmatized: location
# Original: years, Lemmatized: year
# Original: relationships, Lemmatized: relationship
# Original: services, Lemmatized: service
# Original: areas, Lemmatized: area
# Original: years, Lemmatized: year
# Original: systems, Lemmatized: system
# Original: plans, Lemmatized: plan
# Original: benefits, Lemmatized: benefit
# Original: cvs, Lemmatized: cv
# Original: responsibilities, Lemmatized: responsibility
# Original: steps, Lemmatized: step
# Original: policies, Lemmatized: policy
# Original: manuals, Lemmatized: manual
# Original: areas, Lemmatized: area
# Original: clients, Lemmatized: client
# Original: duties, Lemmatized: duty
# Original: requirements, Lemmatized: requirement
# Original: guidelines, Lemmatized: guideline
# Original: regulations, Lemmatized: regulation
# Original: ethics, Lemmatized: ethic
# Original: departments, Lemmatized: department
# Original: messages, Lemmatized: message
# Original: pieces, Lemmatized: piece
# Original: values, Lemmatized: value
# Original: requirements, Lemmatized: requirement
# Original: elements, Lemmatized: element
# Original: discounts, Lemmatized: discount
# Original: reasons, Lemmatized: reason
# Original: opportunities, Lemmatized: opportunity
# Original: reports, Lemmatized: report
# Original: requirements, Lemmatized: requirement
# Original: statements, Lemmatized: statement
# Original: trends, Lemmatized: trend
# Original: strategies, Lemmatized: strategy
# Original: skills, Lemmatized: skill
# Original: analysts, Lemmatized: analyst
# Original: contracts, Lemmatized: contract
# Original: trades, Lemmatized: trade
# Original: books, Lemmatized: book
# Original: processes, Lemmatized: process
# Original: tools, Lemmatized: tool
# Original: methods, Lemmatized: method
# Original: offers, Lemmatized: offer
# Original: institutions, Lemmatized: institution
# Original: solutions, Lemmatized: solution
# Original: details, Lemmatized: detail
# Original: workflows, Lemmatized: workflow
# Original: countries, Lemmatized: country
# Original: serves, Lemmatized: serf
# Original: customers, Lemmatized: customer
# Original: services, Lemmatized: service
# Original: entrepreneurs, Lemmatized: entrepreneur
# Original: roots, Lemmatized: root
# Original: ideas, Lemmatized: idea
# Original: individuals, Lemmatized: individual
# Original: colleagues, Lemmatized: colleague
# Original: markets, Lemmatized: market
# Original: levels, Lemmatized: level
# Original: years, Lemmatized: year
# Original: modules, Lemmatized: module
# Original: certifications, Lemmatized: certification
# Original: offers, Lemmatized: offer
# Original: discuss, Lemmatized: discus
# Original: positions, Lemmatized: position
# Original: partners, Lemmatized: partner
# Original: requirements, Lemmatized: requirement
# Original: professionals, Lemmatized: professional
# Original: relationships, Lemmatized: relationship
# Original: employers, Lemmatized: employer
# Original: pupils, Lemmatized: pupil
# Original: obligations, Lemmatized: obligation
# Original: estates, Lemmatized: estate
# Original: conditions, Lemmatized: condition
# Original: welcomes, Lemmatized: welcome
# Original: sections, Lemmatized: section
# Original: children, Lemmatized: child
# Original: volunteers, Lemmatized: volunteer
# Original: sales, Lemmatized: sale
# Original: seminars, Lemmatized: seminar
# Original: courses, Lemmatized: course
# Original: queries, Lemmatized: query
# Original: areas, Lemmatized: area
# Original: invoices, Lemmatized: invoice
# Original: hours, Lemmatized: hour
# Original: links, Lemmatized: link
# Original: candidates, Lemmatized: candidate
# Original: credentials, Lemmatized: credential
# Original: individuals, Lemmatized: individual
# Original: accounts, Lemmatized: account
# Original: reports, Lemmatized: report
# Original: reconciliations, Lemmatized: reconciliation
# Original: assets, Lemmatized: asset
# Original: statistics, Lemmatized: statistic
# Original: returns, Lemmatized: return
# Original: auditors, Lemmatized: auditor
# Original: advisors, Lemmatized: advisor
# Original: schemes, Lemmatized: scheme
# Original: opportunities, Lemmatized: opportunity
# Original: qualifications, Lemmatized: qualification
# Original: skills, Lemmatized: skill
# Original: benefits, Lemmatized: benefit
# Original: teams, Lemmatized: team
# Original: groups, Lemmatized: group
# Original: wishes, Lemmatized: wish
# Original: means, Lemmatized: mean
# Original: stages, Lemmatized: stage
# Original: levels, Lemmatized: level
# Original: discounts, Lemmatized: discount
# Original: stores, Lemmatized: store
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: operations, Lemmatized: operation
# Original: handlers, Lemmatized: handler
# Original: skills, Lemmatized: skill
# Original: handles, Lemmatized: handle
# Original: classes, Lemmatized: class
# Original: matters, Lemmatized: matter
# Original: underwriters, Lemmatized: underwriter
# Original: claims, Lemmatized: claim
# Original: companies, Lemmatized: company
# Original: regulations, Lemmatized: regulation
# Original: activities, Lemmatized: activity
# Original: systems, Lemmatized: system
# Original: deadlines, Lemmatized: deadline
# Original: events, Lemmatized: event
# Original: opportunities, Lemmatized: opportunity
# Original: requirements, Lemmatized: requirement
# Original: results, Lemmatized: result
# Original: accounts, Lemmatized: account
# Original: skills, Lemmatized: skill
# Original: applicants, Lemmatized: applicant
# Original: days, Lemmatized: day
# Original: affinities, Lemmatized: affinity
# Original: lines, Lemmatized: line
# Original: discuss, Lemmatized: discus
# Original: hours, Lemmatized: hour
# Original: vacancies, Lemmatized: vacancy
# Original: sources, Lemmatized: source
# Original: services, Lemmatized: service
# Original: reports, Lemmatized: report
# Original: activities, Lemmatized: activity
# Original: models, Lemmatized: model
# Original: assess, Lemmatized: ass
# Original: requests, Lemmatized: request
# Original: benefits, Lemmatized: benefit
# Original: actions, Lemmatized: action
# Original: forecasts, Lemmatized: forecast
# Original: assessments, Lemmatized: assessment
# Original: investigations, Lemmatized: investigation
# Original: queries, Lemmatized: query
# Original: starters, Lemmatized: starter
# Original: finishers, Lemmatized: finisher
# Original: duties, Lemmatized: duty
# Original: starts, Lemmatized: start
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: offers, Lemmatized: offer
# Original: hours, Lemmatized: hour
# Original: credentials, Lemmatized: credential
# Original: groups, Lemmatized: group
# Original: companies, Lemmatized: company
# Original: wishes, Lemmatized: wish
# Original: appeals, Lemmatized: appeal
# Original: sales, Lemmatized: sale
# Original: miles, Lemmatized: mile
# Original: hands, Lemmatized: hand
# Original: margins, Lemmatized: margin
# Original: transactions, Lemmatized: transaction
# Original: sales, Lemmatized: sale
# Original: ledgers, Lemmatized: ledger
# Original: accounts, Lemmatized: account
# Original: contracts, Lemmatized: contract
# Original: costs, Lemmatized: cost
# Original: requirements, Lemmatized: requirement
# Original: duties, Lemmatized: duty
# Original: rewards, Lemmatized: reward
# Original: procedures, Lemmatized: procedure
# Original: stakeholders, Lemmatized: stakeholder
# Original: customers, Lemmatized: customer
# Original: queries, Lemmatized: query
# Original: benchmarks, Lemmatized: benchmark
# Original: qualifications, Lemmatized: qualification
# Original: transfers, Lemmatized: transfer
# Original: cheques, Lemmatized: cheque
# Original: procedures, Lemmatized: procedure
# Original: transactions, Lemmatized: transaction
# Original: reviews, Lemmatized: review
# Original: tts, Lemmatized: tt
# Original: costs, Lemmatized: cost
# Original: withdrawals, Lemmatized: withdrawal
# Original: funds, Lemmatized: fund
# Original: items, Lemmatized: item
# Original: auditors, Lemmatized: auditor
# Original: brokers, Lemmatized: broker
# Original: underwriters, Lemmatized: underwriter
# Original: benefits, Lemmatized: benefit
# Original: opportunities, Lemmatized: opportunity
# Original: responses, Lemmatized: response
# Original: candidates, Lemmatized: candidate
# Original: days, Lemmatized: day
# Original: increases, Lemmatized: increase
# Original: statements, Lemmatized: statement
# Original: deadlines, Lemmatized: deadline
# Original: investments, Lemmatized: investment
# Original: consultancies, Lemmatized: consultancy
# Original: systems, Lemmatized: system
# Original: accounts, Lemmatized: account
# Original: payments, Lemmatized: payment
# Original: services, Lemmatized: service
# Original: invoices, Lemmatized: invoice
# Original: suppliers, Lemmatized: supplier
# Original: deadlines, Lemmatized: deadline
# Original: issues, Lemmatized: issue
# Original: targets, Lemmatized: target
# Original: expectations, Lemmatized: expectation
# Original: sessions, Lemmatized: session
# Original: appraisals, Lemmatized: appraisal
# Original: settings, Lemmatized: setting
# Original: creditors, Lemmatized: creditor
# Original: balances, Lemmatized: balance
# Original: timelines, Lemmatized: timeline
# Original: systems, Lemmatized: system
# Original: audits, Lemmatized: audit
# Original: projects, Lemmatized: project
# Original: opportunities, Lemmatized: opportunity
# Original: projects, Lemmatized: project
# Original: duties, Lemmatized: duty
# Original: standards, Lemmatized: standard
# Original: deadlines, Lemmatized: deadline
# Original: responsibilities, Lemmatized: responsibility
# Original: areas, Lemmatized: area
# Original: justifications, Lemmatized: justification
# Original: communications, Lemmatized: communication
# Original: systems, Lemmatized: system
# Original: equivalents, Lemmatized: equivalent
# Original: days, Lemmatized: day
# Original: years, Lemmatized: year
# Original: exams, Lemmatized: exam
# Original: courses, Lemmatized: course
# Original: prospects, Lemmatized: prospect
# Original: responsibilities, Lemmatized: responsibility
# Original: statements, Lemmatized: statement
# Original: traders, Lemmatized: trader
# Original: companies, Lemmatized: company
# Original: partnerships, Lemmatized: partnership
# Original: managements, Lemmatized: management
# Original: months, Lemmatized: month
# Original: instances, Lemmatized: instance
# Original: days, Lemmatized: day
# Original: professionals, Lemmatized: professional
# Original: areas, Lemmatized: area
# Original: roots, Lemmatized: root
# Original: midlands, Lemmatized: midland
# Original: consultants, Lemmatized: consultant
# Original: associates, Lemmatized: associate
# Original: responsibilities, Lemmatized: responsibility
# Original: costs, Lemmatized: cost
# Original: controls, Lemmatized: control
# Original: obligations, Lemmatized: obligation
# Original: transfers, Lemmatized: transfer
# Original: schedules, Lemmatized: schedule
# Original: relationships, Lemmatized: relationship
# Original: cultures, Lemmatized: culture
# Original: levels, Lemmatized: level
# Original: colleagues, Lemmatized: colleague
# Original: problems, Lemmatized: problem
# Original: tasks, Lemmatized: task
# Original: options, Lemmatized: option
# Original: objectives, Lemmatized: objective
# Original: estates, Lemmatized: estate
# Original: allocations, Lemmatized: allocation
# Original: employees, Lemmatized: employee
# Original: cvs, Lemmatized: cv
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: details, Lemmatized: detail
# Original: firms, Lemmatized: firm
# Original: approaches, Lemmatized: approach
# Original: greeks, Lemmatized: greek
# Original: metrics, Lemmatized: metric
# Original: offers, Lemmatized: offer
# Original: plans, Lemmatized: plan
# Original: details, Lemmatized: detail
# Original: outskirts, Lemmatized: outskirt
# Original: deadlines, Lemmatized: deadline
# Original: expenses, Lemmatized: expense
# Original: documentations, Lemmatized: documentation
# Original: contributions, Lemmatized: contribution
# Original: sounds, Lemmatized: sound
# Original: duties, Lemmatized: duty
# Original: sections, Lemmatized: section
# Original: policies, Lemmatized: policy
# Original: resources, Lemmatized: resource
# Original: shortfalls, Lemmatized: shortfall
# Original: plans, Lemmatized: plan
# Original: issues, Lemmatized: issue
# Original: managers, Lemmatized: manager
# Original: custodians, Lemmatized: custodian
# Original: operations, Lemmatized: operation
# Original: developments, Lemmatized: development
# Original: procedures, Lemmatized: procedure
# Original: stakeholders, Lemmatized: stakeholder
# Original: levels, Lemmatized: level
# Original: assumptions, Lemmatized: assumption
# Original: principles, Lemmatized: principle
# Original: solutions, Lemmatized: solution
# Original: obstacles, Lemmatized: obstacle
# Original: architectures, Lemmatized: architecture
# Original: grounds, Lemmatized: ground
# Original: communications, Lemmatized: communication
# Original: systems, Lemmatized: system
# Original: standards, Lemmatized: standard
# Original: regulations, Lemmatized: regulation
# Original: papers, Lemmatized: paper
# Original: reports, Lemmatized: report
# Original: problems, Lemmatized: problem
# Original: officers, Lemmatized: officer
# Original: improvements, Lemmatized: improvement
# Original: recommendations, Lemmatized: recommendation
# Original: meetings, Lemmatized: meeting
# Original: objectives, Lemmatized: objective
# Original: interviews, Lemmatized: interview
# Original: members, Lemmatized: member
# Original: gaps, Lemmatized: gap
# Original: disciplines, Lemmatized: discipline
# Original: updates, Lemmatized: update
# Original: volumes, Lemmatized: volume
# Original: cvs, Lemmatized: cv
# Original: ads, Lemmatized: ad
# Original: consultants, Lemmatized: consultant
# Original: requirements, Lemmatized: requirement
# Original: graduates, Lemmatized: graduate
# Original: individuals, Lemmatized: individual
# Original: careers, Lemmatized: career
# Original: applicants, Lemmatized: applicant
# Original: processes, Lemmatized: process
# Original: documents, Lemmatized: document
# Original: trustees, Lemmatized: trustee
# Original: members, Lemmatized: member
# Original: indicators, Lemmatized: indicator
# Original: aspects, Lemmatized: aspect
# Original: meets, Lemmatized: meet
# Original: requirements, Lemmatized: requirement
# Original: guidelines, Lemmatized: guideline
# Original: tasks, Lemmatized: task
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: months, Lemmatized: month
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: services, Lemmatized: service
# Original: names, Lemmatized: name
# Original: businesses, Lemmatized: business
# Original: benefits, Lemmatized: benefit
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: responsibilities, Lemmatized: responsibility
# Original: invoices, Lemmatized: invoice
# Original: suppliers, Lemmatized: supplier
# Original: claims, Lemmatized: claim
# Original: payments, Lemmatized: payment
# Original: rejects, Lemmatized: reject
# Original: members, Lemmatized: member
# Original: accounts, Lemmatized: account
# Original: duties, Lemmatized: duty
# Original: deadlines, Lemmatized: deadline
# Original: skills, Lemmatized: skill
# Original: applications, Lemmatized: application
# Original: appointments, Lemmatized: appointment
# Original: assignments, Lemmatized: assignment
# Original: procedures, Lemmatized: procedure
# Original: reviews, Lemmatized: review
# Original: risks, Lemmatized: risk
# Original: plans, Lemmatized: plan
# Original: skills, Lemmatized: skill
# Original: figures, Lemmatized: figure
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: architectures, Lemmatized: architecture
# Original: services, Lemmatized: service
# Original: tools, Lemmatized: tool
# Original: systems, Lemmatized: system
# Original: pensions, Lemmatized: pension
# Original: solutions, Lemmatized: solution
# Original: members, Lemmatized: member
# Original: offers, Lemmatized: offer
# Original: forecasts, Lemmatized: forecast
# Original: payments, Lemmatized: payment
# Original: codes, Lemmatized: code
# Original: centres, Lemmatized: centre
# Original: systems, Lemmatized: system
# Original: queries, Lemmatized: query
# Original: managers, Lemmatized: manager
# Original: procedures, Lemmatized: procedure
# Original: months, Lemmatized: month
# Original: seeks, Lemmatized: seek
# Original: standards, Lemmatized: standard
# Original: exercises, Lemmatized: exercise
# Original: reports, Lemmatized: report
# Original: minutes, Lemmatized: minute
# Original: calculations, Lemmatized: calculation
# Original: recommendations, Lemmatized: recommendation
# Original: mitigations, Lemmatized: mitigation
# Original: responses, Lemmatized: response
# Original: requirements, Lemmatized: requirement
# Original: matters, Lemmatized: matter
# Original: purposes, Lemmatized: purpose
# Original: improvements, Lemmatized: improvement
# Original: discuss, Lemmatized: discus
# Original: goals, Lemmatized: goal
# Original: employees, Lemmatized: employee
# Original: starters, Lemmatized: starter
# Original: procedures, Lemmatized: procedure
# Original: expenses, Lemmatized: expense
# Original: days, Lemmatized: day
# Original: years, Lemmatized: year
# Original: returns, Lemmatized: return
# Original: prospects, Lemmatized: prospect
# Original: projects, Lemmatized: project
# Original: members, Lemmatized: member
# Original: managers, Lemmatized: manager
# Original: relationships, Lemmatized: relationship
# Original: years, Lemmatized: year
# Original: prides, Lemmatized: pride
# Original: requirements, Lemmatized: requirement
# Original: drivers, Lemmatized: driver
# Original: vulnerabilities, Lemmatized: vulnerability
# Original: rules, Lemmatized: rule
# Original: scenarios, Lemmatized: scenario
# Original: results, Lemmatized: result
# Original: skills, Lemmatized: skill
# Original: responsibilities, Lemmatized: responsibility
# Original: duties, Lemmatized: duty
# Original: units, Lemmatized: unit
# Original: projects, Lemmatized: project
# Original: possess, Lemmatized: posse
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: accounts, Lemmatized: account
# Original: records, Lemmatized: record
# Original: valuations, Lemmatized: valuation
# Original: areas, Lemmatized: area
# Original: developments, Lemmatized: development
# Original: services, Lemmatized: service
# Original: processes, Lemmatized: process
# Original: solutions, Lemmatized: solution
# Original: duties, Lemmatized: duty
# Original: structures, Lemmatized: structure
# Original: indicators, Lemmatized: indicator
# Original: parts, Lemmatized: part
# Original: budgets, Lemmatized: budget
# Original: directors, Lemmatized: director
# Original: matters, Lemmatized: matter
# Original: returns, Lemmatized: return
# Original: reconciliations, Lemmatized: reconciliation
# Original: checks, Lemmatized: check
# Original: reports, Lemmatized: report
# Original: statements, Lemmatized: statement
# Original: runs, Lemmatized: run
# Original: customers, Lemmatized: customer
# Original: employs, Lemmatized: employ
# Original: managers, Lemmatized: manager
# Original: months, Lemmatized: month
# Original: systems, Lemmatized: system
# Original: solutions, Lemmatized: solution
# Original: connections, Lemmatized: connection
# Original: skills, Lemmatized: skill
# Original: centres, Lemmatized: centre
# Original: ventures, Lemmatized: venture
# Original: propositions, Lemmatized: proposition
# Original: applicants, Lemmatized: applicant
# Original: services, Lemmatized: service
# Original: duties, Lemmatized: duty
# Original: calls, Lemmatized: call
# Original: acts, Lemmatized: act
# Original: workers, Lemmatized: worker
# Original: disclaimers, Lemmatized: disclaimer
# Original: takes, Lemmatized: take
# Original: requirements, Lemmatized: requirement
# Original: classes, Lemmatized: class
# Original: offers, Lemmatized: offer
# Original: years, Lemmatized: year
# Original: derivatives, Lemmatized: derivative
# Original: expenses, Lemmatized: expense
# Original: disputes, Lemmatized: dispute
# Original: responsibilities, Lemmatized: responsibility
# Original: conditions, Lemmatized: condition
# Original: statements, Lemmatized: statement
# Original: responses, Lemmatized: response
# Original: terms, Lemmatized: term
# Original: specialists, Lemmatized: specialist
# Original: cases, Lemmatized: case
# Original: auditors, Lemmatized: auditor
# Original: bills, Lemmatized: bill
# Original: parties, Lemmatized: party
# Original: limitations, Lemmatized: limitation
# Original: managers, Lemmatized: manager
# Original: numbers, Lemmatized: number
# Original: bids, Lemmatized: bid
# Original: reviews, Lemmatized: review
# Original: calculations, Lemmatized: calculation
# Original: budgets, Lemmatized: budget
# Original: accounts, Lemmatized: account
# Original: costs, Lemmatized: cost
# Original: margins, Lemmatized: margin
# Original: opportunities, Lemmatized: opportunity
# Original: candidates, Lemmatized: candidate
# Original: applicants, Lemmatized: applicant
# Original: days, Lemmatized: day
# Original: providers, Lemmatized: provider
# Original: communications, Lemmatized: communication
# Original: offers, Lemmatized: offer
# Original: solutions, Lemmatized: solution
# Original: applications, Lemmatized: application
# Original: devices, Lemmatized: device
# Original: networks, Lemmatized: network
# Original: teams, Lemmatized: team
# Original: departments, Lemmatized: department
# Original: profiles, Lemmatized: profile
# Original: requirements, Lemmatized: requirement
# Original: specifications, Lemmatized: specification
# Original: presentations, Lemmatized: presentation
# Original: audiences, Lemmatized: audience
# Original: partners, Lemmatized: partner
# Original: opportunities, Lemmatized: opportunity
# Original: words, Lemmatized: word
# Original: services, Lemmatized: service
# Original: candidates, Lemmatized: candidate
# Original: clients, Lemmatized: client
# Original: responsibilities, Lemmatized: responsibility
# Original: recommendations, Lemmatized: recommendation
# Original: systems, Lemmatized: system
# Original: policies, Lemmatized: policy
# Original: procedures, Lemmatized: procedure
# Original: results, Lemmatized: result
# Original: divisions, Lemmatized: division
# Original: requirements, Lemmatized: requirement
# Original: relationships, Lemmatized: relationship
# Original: days, Lemmatized: day
# Original: weaknesses, Lemmatized: weakness
# Original: limitations, Lemmatized: limitation
# Original: results, Lemmatized: result
# Original: methodologies, Lemmatized: methodology
# Original: calculations, Lemmatized: calculation
# Original: developers, Lemmatized: developer
# Original: managers, Lemmatized: manager
# Original: auditors, Lemmatized: auditor
# Original: steps, Lemmatized: step
# Original: rules, Lemmatized: rule
# Original: equations, Lemmatized: equation
# Original: methods, Lemmatized: method
# Original: solutions, Lemmatized: solution
# Original: seeks, Lemmatized: seek
# Original: banks, Lemmatized: bank
# Original: managers, Lemmatized: manager
# Original: offers, Lemmatized: offer
# Original: problems, Lemmatized: problem
# Original: queries, Lemmatized: query
# Original: classes, Lemmatized: class
# Original: environments, Lemmatized: environment
# Original: operations, Lemmatized: operation
# Original: deadlines, Lemmatized: deadline
# Original: skills, Lemmatized: skill
# Original: positions, Lemmatized: position
# Original: months, Lemmatized: month
# Original: options, Lemmatized: option
# Original: days, Lemmatized: day
# Original: qualifications, Lemmatized: qualification
# Original: qualities, Lemmatized: quality
# Original: months, Lemmatized: month
# Original: solicitors, Lemmatized: solicitor
# Original: rules, Lemmatized: rule
# Original: colleagues, Lemmatized: colleague
# Original: occasions, Lemmatized: occasion
# Original: companies, Lemmatized: company
# Original: directors, Lemmatized: director
# Original: agencies, Lemmatized: agency
# Original: findings, Lemmatized: finding
# Original: tests, Lemmatized: test
# Original: tools, Lemmatized: tool
# Original: requests, Lemmatized: request
# Original: polices, Lemmatized: police
# Original: units, Lemmatized: unit
# Original: instruments, Lemmatized: instrument
# Original: amounts, Lemmatized: amount
# Original: aspects, Lemmatized: aspect
# Original: receipts, Lemmatized: receipt
# Original: sales, Lemmatized: sale
# Original: duties, Lemmatized: duty
# Original: systems, Lemmatized: system
# Original: possess, Lemmatized: posse
# Original: attributes, Lemmatized: attribute
# Original: skills, Lemmatized: skill
# Original: opportunities, Lemmatized: opportunity
# Original: benefits, Lemmatized: benefit
# Original: rates, Lemmatized: rate
# Original: rewards, Lemmatized: reward
# Original: claims, Lemmatized: claim
# Original: regions, Lemmatized: region
# Original: codes, Lemmatized: code
# Original: woods, Lemmatized: wood
# Original: ceramics, Lemmatized: ceramic
# Original: products, Lemmatized: product
# Original: sales, Lemmatized: sale
# Original: procedures, Lemmatized: procedure
# Original: branches, Lemmatized: branch
# Original: brands, Lemmatized: brand
# Original: sales, Lemmatized: sale
# Original: employees, Lemmatized: employee
# Original: enquiries, Lemmatized: enquiry
# Original: arrangements, Lemmatized: arrangement
# Original: types, Lemmatized: type
# Original: procedures, Lemmatized: procedure
# Original: resources, Lemmatized: resource
# Original: matters, Lemmatized: matter
# Original: systems, Lemmatized: system
# Original: candidates, Lemmatized: candidate
# Original: responsibilities, Lemmatized: responsibility
# Original: controls, Lemmatized: control
# Original: systems, Lemmatized: system
# Original: deliverables, Lemmatized: deliverable
# Original: relationships, Lemmatized: relationship
# Original: projects, Lemmatized: project
# Original: regulations, Lemmatized: regulation
# Original: masters, Lemmatized: master
# Original: maths, Lemmatized: math
# Original: accounts, Lemmatized: account
# Original: sales, Lemmatized: sale
# Original: systems, Lemmatized: system
# Original: processes, Lemmatized: process
# Original: skills, Lemmatized: skill
# Original: locations, Lemmatized: location
# Original: applicants, Lemmatized: applicant
# Original: queries, Lemmatized: query
# Original: reconciliations, Lemmatized: reconciliation
# Original: appraisals, Lemmatized: appraisal
# Original: skills, Lemmatized: skill
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: brands, Lemmatized: brand
# Original: levels, Lemmatized: level
# Original: discounts, Lemmatized: discount
# Original: candidates, Lemmatized: candidate
# Original: credentials, Lemmatized: credential
# Original: opportunities, Lemmatized: opportunity
# Original: qualifications, Lemmatized: qualification
# Original: providers, Lemmatized: provider
# Original: clients, Lemmatized: client
# Original: payments, Lemmatized: payment
# Original: duties, Lemmatized: duty
# Original: levels, Lemmatized: level
# Original: members, Lemmatized: member
# Original: trustees, Lemmatized: trustee
# Original: stakeholders, Lemmatized: stakeholder
# Original: applicants, Lemmatized: applicant
# Original: candidates, Lemmatized: candidate
# Original: colleagues, Lemmatized: colleague
# Original: members, Lemmatized: member
# Original: assignments, Lemmatized: assignment
# Original: initiatives, Lemmatized: initiative
# Original: requirements, Lemmatized: requirement
# Original: relationships, Lemmatized: relationship
# Original: skills, Lemmatized: skill
# Original: capabilities, Lemmatized: capability
# Original: professionals, Lemmatized: professional
# Original: months, Lemmatized: month
# Original: services, Lemmatized: service
# Original: teams, Lemmatized: team
# Original: analysts, Lemmatized: analyst
# Original: facilitators, Lemmatized: facilitator
# Original: accountabilities, Lemmatized: accountability
# Original: stages, Lemmatized: stage
# Original: standards, Lemmatized: standard
# Original: studies, Lemmatized: study
# Original: contractors, Lemmatized: contractor
# Original: incentives, Lemmatized: incentive
# Original: skills, Lemmatized: skill
# Original: qualifications, Lemmatized: qualification
# Original: aspects, Lemmatized: aspect
# Original: models, Lemmatized: model
# Original: results, Lemmatized: result
# Original: actions, Lemmatized: action
# Original: techniques, Lemmatized: technique
# Original: challenges, Lemmatized: challenge
# Original: habits, Lemmatized: habit
# Original: projects, Lemmatized: project
# Original: aims, Lemmatized: aim
# Original: skills, Lemmatized: skill
# Original: finances, Lemmatized: finance
# Original: functions, Lemmatized: function
# Original: families, Lemmatized: family
# Original: ideas, Lemmatized: idea
# Original: responsibilities, Lemmatized: responsibility
# Original: months, Lemmatized: month
# Original: interviews, Lemmatized: interview
# Original: technicians, Lemmatized: technician
# Original: returns, Lemmatized: return
# Original: registrations, Lemmatized: registration
# Original: packs, Lemmatized: pack
# Original: members, Lemmatized: member
# Original: possess, Lemmatized: posse
# Original: attributes, Lemmatized: attribute
# Original: areas, Lemmatized: area
# Original: issues, Lemmatized: issue
# Original: inefficiencies, Lemmatized: inefficiency
# Original: transactions, Lemmatized: transaction
# Original: individuals, Lemmatized: individual
# Original: ages, Lemmatized: age
# Original: backgrounds, Lemmatized: background
# Original: candidates, Lemmatized: candidate
# Original: acts, Lemmatized: act
# Original: regulations, Lemmatized: regulation
# Original: places, Lemmatized: place
# Original: opportunities, Lemmatized: opportunity
# Original: directors, Lemmatized: director
# Original: figures, Lemmatized: figure
# Original: targets, Lemmatized: target
# Original: projects, Lemmatized: project
# Original: academics, Lemmatized: academic
# Original: possess, Lemmatized: posse
# Original: colleagues, Lemmatized: colleague
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: days, Lemmatized: day
# Original: details, Lemmatized: detail
# Original: benefits, Lemmatized: benefit
# Original: operations, Lemmatized: operation
# Original: implementations, Lemmatized: implementation
# Original: years, Lemmatized: year
# Original: products, Lemmatized: product
# Original: marks, Lemmatized: mark
# Original: versions, Lemmatized: version
# Original: deadlines, Lemmatized: deadline
# Original: bonuses, Lemmatized: bonus
# Original: discuss, Lemmatized: discus
# Original: means, Lemmatized: mean
# Original: permits, Lemmatized: permit
# Original: requirements, Lemmatized: requirement
# Original: relationships, Lemmatized: relationship
# Original: employers, Lemmatized: employer
# Original: systems, Lemmatized: system
# Original: targets, Lemmatized: target
# Original: duties, Lemmatized: duty
# Original: contracts, Lemmatized: contract
# Original: reports, Lemmatized: report
# Original: holders, Lemmatized: holder
# Original: improvements, Lemmatized: improvement
# Original: applicants, Lemmatized: applicant
# Original: skills, Lemmatized: skill
# Original: decisions, Lemmatized: decision
# Original: seeks, Lemmatized: seek
# Original: terms, Lemmatized: term
# Original: relationships, Lemmatized: relationship
# Original: brokers, Lemmatized: broker
# Original: targets, Lemmatized: target
# Original: cases, Lemmatized: case
# Original: reports, Lemmatized: report
# Original: scrutinies, Lemmatized: scrutiny
# Original: levels, Lemmatized: level
# Original: qualities, Lemmatized: quality
# Original: applications, Lemmatized: application
# Original: individuals, Lemmatized: individual
# Original: ages, Lemmatized: age
# ...
# Original: assess, Lemmatized: ass
# Original: trends, Lemmatized: trend
# Original: audiences, Lemmatized: audience
# Original: strategies, Lemmatized: strategy
# Original: sales, Lemmatized: sale
# Original: relationships, Lemmatized: relationship
# Original: vendors, Lemmatized: vendor
# Original: years, Lemmatized: year
# Original: customers, Lemmatized: customer
# Original: multiples, Lemmatized: multiple
# Original: items, Lemmatized: item
# Original: morrisons, Lemmatized: morrison
# Original: areas, Lemmatized: area
# Original: members, Lemmatized: member
# Original: visits, Lemmatized: visit
# Original: pensions, Lemmatized: pension
# Original: acts, Lemmatized: act
# Original: workers, Lemmatized: worker
# Original: disclaimers, Lemmatized: disclaimer
# Original: services, Lemmatized: service
# Original: errors, Lemmatized: error
# Original: costs, Lemmatized: cost
# Original: policies, Lemmatized: policy
# Original: individuals, Lemmatized: individual
# Original: packages, Lemmatized: package
# Original: customers, Lemmatized: customer
# Original: deals, Lemmatized: deal
# Original: performers, Lemmatized: performer
# Original: aspirations, Lemmatized: aspiration
# Original: candidates, Lemmatized: candidate
# Original: discuss, Lemmatized: discus
# Original: positions, Lemmatized: position
# Original: bms, Lemmatized: bm
# Original: years, Lemmatized: year
# Original: professionals, Lemmatized: professional
# Original: telecoms, Lemmatized: telecom
# Original: requirements, Lemmatized: requirement
# Original: products, Lemmatized: product
# Original: theatres, Lemmatized: theatre
# Original: surgeons, Lemmatized: surgeon
# Original: days, Lemmatized: day
# Original: centres, Lemmatized: centre
# Original: clients, Lemmatized: client
# Original: offers, Lemmatized: offer
# Original: jobs, Lemmatized: job
# Original: trainees, Lemmatized: trainee
# Original: representatives, Lemmatized: representative
# Original: engineers, Lemmatized: engineer
# Original: teams, Lemmatized: team
# Original: sectors, Lemmatized: sector
# Original: days, Lemmatized: day
# Original: benefits, Lemmatized: benefit
# Original: wholesalers, Lemmatized: wholesaler
# Original: years, Lemmatized: year
# Original: terms, Lemmatized: term
# Original: reasons, Lemmatized: reason
# Original: embraces, Lemmatized: embrace
# Original: values, Lemmatized: value
# Original: applicants, Lemmatized: applicant
# Original: hobbies, Lemmatized: hobby
# Original: friends, Lemmatized: friend
# Original: aspirations, Lemmatized: aspiration
# Original: relationships, Lemmatized: relationship
# Original: ingredients, Lemmatized: ingredient
# Original: hundreds, Lemmatized: hundred
# Original: sales, Lemmatized: sale
# Original: helps, Lemmatized: help
# Original: sizes, Lemmatized: size
# Original: products, Lemmatized: product
# Original: journalists, Lemmatized: journalist
# Original: consumers, Lemmatized: consumer
# Original: platforms, Lemmatized: platform
# Original: offers, Lemmatized: offer
# Original: results, Lemmatized: result
# Original: objectives, Lemmatized: objective
# Original: levels, Lemmatized: level
# Original: benefits, Lemmatized: benefit
# Original: issues, Lemmatized: issue
# Original: expectations, Lemmatized: expectation
# Original: requirements, Lemmatized: requirement
# Original: deadlines, Lemmatized: deadline
# Original: suppliers, Lemmatized: supplier
# Original: ports, Lemmatized: port
# Original: locations, Lemmatized: location
# Original: products, Lemmatized: product
# Original: winches, Lemmatized: winch
# Original: hoists, Lemmatized: hoist
# Original: requirements, Lemmatized: requirement
# Original: materials, Lemmatized: material
# Original: candidates, Lemmatized: candidate
# Original: recruiters, Lemmatized: recruiter
# Original: experts, Lemmatized: expert
# Original: providers, Lemmatized: provider
# Original: films, Lemmatized: film
# Original: games, Lemmatized: game
# Original: shows, Lemmatized: show
# Original: residences, Lemmatized: residence
# Original: applicants, Lemmatized: applicant
# Original: operations, Lemmatized: operation
# Original: participants, Lemmatized: participant
# Original: pages, Lemmatized: page
# Original: events, Lemmatized: event
# Original: members, Lemmatized: member
# Original: shoppers, Lemmatized: shopper
# Original: services, Lemmatized: service
# Original: kits, Lemmatized: kit
# Original: schools, Lemmatized: school
# Original: authorities, Lemmatized: authority
# Original: retailers, Lemmatized: retailer
# Original: responsibilities, Lemmatized: responsibility
# Original: reviews, Lemmatized: review
# Original: individuals, Lemmatized: individual
# Original: criteria, Lemmatized: criterion
# Original: days, Lemmatized: day
# Original: jobs, Lemmatized: job
# Original: offices, Lemmatized: office
# Original: meetings, Lemmatized: meeting
# Original: duties, Lemmatized: duty
# Original: makers, Lemmatized: maker
# Original: appointments, Lemmatized: appointment
# Original: leads, Lemmatized: lead
# Original: clients, Lemmatized: client
# Original: customers, Lemmatized: customer
# Original: products, Lemmatized: product
# Original: targets, Lemmatized: target
# Original: hours, Lemmatized: hour
# Original: teams, Lemmatized: team
# Original: responsibilities, Lemmatized: responsibility
# Original: visas, Lemmatized: visa
# Original: weeks, Lemmatized: week
# Original: incentives, Lemmatized: incentive
# Original: providers, Lemmatized: provider
# Original: events, Lemmatized: event
# Original: leaders, Lemmatized: leader
# Original: advisors, Lemmatized: advisor
# Original: consultations, Lemmatized: consultation
# Original: sessions, Lemmatized: session
# Original: memberships, Lemmatized: membership
# Original: bikes, Lemmatized: bike
# Original: earners, Lemmatized: earner
# Original: agents, Lemmatized: agent
# Original: takes, Lemmatized: take
# Original: requirements, Lemmatized: requirement
# Original: continents, Lemmatized: continent
# Original: shops, Lemmatized: shop
# Original: philosophies, Lemmatized: philosophy
# Original: goals, Lemmatized: goal
# Original: hours, Lemmatized: hour
# Original: programmes, Lemmatized: programme
# Original: courses, Lemmatized: course
# Original: qualifications, Lemmatized: qualification
# Original: conferences, Lemmatized: conference
# Original: challenges, Lemmatized: challenge
# Original: discuss, Lemmatized: discus
# Original: vacancies, Lemmatized: vacancy
# Original: consultants, Lemmatized: consultant
# Original: skills, Lemmatized: skill
# Original: engineers, Lemmatized: engineer
# Original: documents, Lemmatized: document
# Original: contracts, Lemmatized: contract
# Original: offers, Lemmatized: offer
# Original: professionals, Lemmatized: professional
# Original: projects, Lemmatized: project
# Original: materials, Lemmatized: material
# Original: reports, Lemmatized: report
# Original: applications, Lemmatized: application
# Original: midlands, Lemmatized: midland
# Original: retailers, Lemmatized: retailer
# Original: prospects, Lemmatized: prospect
# Original: plans, Lemmatized: plan
# Original: individuals, Lemmatized: individual
# Original: attributes, Lemmatized: attribute
# Original: furnishings, Lemmatized: furnishing
# Original: lots, Lemmatized: lot
# Original: products, Lemmatized: product
# Original: services, Lemmatized: service
# Original: brands, Lemmatized: brand
# Original: wales, Lemmatized: wale
# Original: beds, Lemmatized: bed
# Original: individuals, Lemmatized: individual
# Original: years, Lemmatized: year
# Original: businesses, Lemmatized: business
# Original: consumers, Lemmatized: consumer
# Original: options, Lemmatized: option
# Original: fees, Lemmatized: fee
# Original: deals, Lemmatized: deal
# Original: skills, Lemmatized: skill
# Original: advisors, Lemmatized: advisor
# Original: positions, Lemmatized: position
# Original: competitors, Lemmatized: competitor
# Original: possibilities, Lemmatized: possibility
# Original: years, Lemmatized: year
# Original: deals, Lemmatized: deal
# Original: maths, Lemmatized: math
# Original: statistics, Lemmatized: statistic
# Original: languages, Lemmatized: language
# Original: cycles, Lemmatized: cycle
# Original: accounts, Lemmatized: account
# Original: candidates, Lemmatized: candidate
# Original: sales, Lemmatized: sale
# Original: targets, Lemmatized: target
# Original: employees, Lemmatized: employee
# Original: applicants, Lemmatized: applicant
# Original: hours, Lemmatized: hour
# Original: goals, Lemmatized: goal
# Original: starts, Lemmatized: start
# Original: saturdays, Lemmatized: saturday
# Original: duties, Lemmatized: duty
# Original: calls, Lemmatized: call
# Original: products, Lemmatized: product
# Original: appointments, Lemmatized: appointment
# Original: advisors, Lemmatized: advisor
# Original: candidates, Lemmatized: candidate
# Original: possess, Lemmatized: posse
# Original: skills, Lemmatized: skill
# Original: hours, Lemmatized: hour
# Original: days, Lemmatized: day
# Original: operations, Lemmatized: operation
# Original: cities, Lemmatized: city
# Original: countries, Lemmatized: country
# Original: relationships, Lemmatized: relationship
# Original: campaigns, Lemmatized: campaign
# Original: opportunities, Lemmatized: opportunity
# Original: possess, Lemmatized: posse
# Original: skills, Lemmatized: skill
# Original: experts, Lemmatized: expert
# Original: positions, Lemmatized: position
# Original: pages, Lemmatized: page
# Original: backgrounds, Lemmatized: background
# Original: owners, Lemmatized: owner
# Original: mums, Lemmatized: mum
# Original: dads, Lemmatized: dad
# Original: climates, Lemmatized: climate
# Original: rewards, Lemmatized: reward
# Original: earners, Lemmatized: earner
# Original: days, Lemmatized: day
# Original: leads, Lemmatized: lead
# Original: interviews, Lemmatized: interview
# Original: sizes, Lemmatized: size
# Original: deals, Lemmatized: deal
# Original: targets, Lemmatized: target
# Original: benefits, Lemmatized: benefit
# Original: vacancies, Lemmatized: vacancy
# Original: executives, Lemmatized: executive
# Original: responsibilities, Lemmatized: responsibility
# Original: sales, Lemmatized: sale
# Original: manufacturers, Lemmatized: manufacturer
# Original: criteria, Lemmatized: criterion
# Original: applicants, Lemmatized: applicant
# Original: matches, Lemmatized: match
# Original: requirements, Lemmatized: requirement
# Original: vacancies, Lemmatized: vacancy
# Original: years, Lemmatized: year
# Original: offices, Lemmatized: office
# Original: solutions, Lemmatized: solution
# Original: organisations, Lemmatized: organisation
# Original: sectors, Lemmatized: sector
# Original: consultancies, Lemmatized: consultancy
# Original: businesses, Lemmatized: business
# Original: weekdays, Lemmatized: weekday
# Original: saturdays, Lemmatized: saturday
# Original: details, Lemmatized: detail
# Original: applications, Lemmatized: application
# Original: aspects, Lemmatized: aspect
# Original: loans, Lemmatized: loan
# Original: books, Lemmatized: book
# Original: borrowers, Lemmatized: borrower
# Original: lenders, Lemmatized: lender
# Original: dealers, Lemmatized: dealer
# Original: sales, Lemmatized: sale
# Original: resources, Lemmatized: resource
# Original: subsidiaries, Lemmatized: subsidiary
# Original: states, Lemmatized: state
# Original: solutions, Lemmatized: solution
# Original: divisions, Lemmatized: division
# Original: pass, Lemmatized: pas
# Original: tests, Lemmatized: test
# Original: years, Lemmatized: year
# Original: fees, Lemmatized: fee
# Original: responsibilities, Lemmatized: responsibility
# Original: activities, Lemmatized: activity
# Original: details, Lemmatized: detail
# Original: parties, Lemmatized: party
# Original: distributors, Lemmatized: distributor
# Original: sales, Lemmatized: sale
# Original: benefits, Lemmatized: benefit
# Original: candidates, Lemmatized: candidate
# Original: credentials, Lemmatized: credential
# Original: days, Lemmatized: day
# Original: qualifications, Lemmatized: qualification
# Original: equivalents, Lemmatized: equivalent
# Original: benefits, Lemmatized: benefit
# Original: incentives, Lemmatized: incentive
# Original: incomes, Lemmatized: income
# Original: cheques, Lemmatized: cheque
# Original: directors, Lemmatized: director
# Original: firms, Lemmatized: firm
# Original: packages, Lemmatized: package
# Original: prospects, Lemmatized: prospect
# Original: tools, Lemmatized: tool
# Original: traits, Lemmatized: trait
# Original: sacrifices, Lemmatized: sacrifice
# Original: expectations, Lemmatized: expectation
# Original: pass, Lemmatized: pas
# Original: meetings, Lemmatized: meeting
# Original: slots, Lemmatized: slot
# Original: results, Lemmatized: result
# Original: plans, Lemmatized: plan
# Original: negotiations, Lemmatized: negotiation
# Original: offices, Lemmatized: office
# Original: benefits, Lemmatized: benefit
# Original: countries, Lemmatized: country
# Original: professionals, Lemmatized: professional
# Original: customers, Lemmatized: customer
# Original: techniques, Lemmatized: technique
# Original: skills, Lemmatized: skill
# Original: surgeons, Lemmatized: surgeon
# Original: relationships, Lemmatized: relationship
# Original: levels, Lemmatized: level
# Original: years, Lemmatized: year
# Original: advisers, Lemmatized: adviser
# Original: executives, Lemmatized: executive
# Original: directors, Lemmatized: director
# Original: instruments, Lemmatized: instrument
# Original: stakeholders, Lemmatized: stakeholder
# Original: targets, Lemmatized: target
# Original: expectations, Lemmatized: expectation
# Original: areas, Lemmatized: area
# Original: programmes, Lemmatized: programme
# Original: demands, Lemmatized: demand
# Original: stages, Lemmatized: stage
# Original: parameters, Lemmatized: parameter
# Original: departments, Lemmatized: department
# Original: directorates, Lemmatized: directorate
# Original: functions, Lemmatized: function
# Original: avenues, Lemmatized: avenue
# Original: objectives, Lemmatized: objective
# Original: interviews, Lemmatized: interview
# Original: schools, Lemmatized: school
# Original: benefits, Lemmatized: benefit
# Original: sells, Lemmatized: sell
# Original: suites, Lemmatized: suite
# Original: costings, Lemmatized: costing
# Original: departments, Lemmatized: department
# Original: contracts, Lemmatized: contract
# Original: periods, Lemmatized: period
# Original: months, Lemmatized: month
# Original: cycles, Lemmatized: cycle
# Original: amounts, Lemmatized: amount
# Original: days, Lemmatized: day
# Original: holidays, Lemmatized: holiday
# Original: centres, Lemmatized: centre
# Original: clients, Lemmatized: client
# Original: trainees, Lemmatized: trainee
# Original: representatives, Lemmatized: representative
# Original: advisors, Lemmatized: advisor
# Original: opportunities, Lemmatized: opportunity
# Original: applicants, Lemmatized: applicant
# Original: teams, Lemmatized: team
# Original: sectors, Lemmatized: sector
# Original: consultants, Lemmatized: consultant
# Original: markets, Lemmatized: market
# Original: years, Lemmatized: year
# Original: leads, Lemmatized: lead
# Original: duties, Lemmatized: duty
# Original: exhibitions, Lemmatized: exhibition
# Original: offers, Lemmatized: offer
# Original: services, Lemmatized: service
# Original: fairs, Lemmatized: fair
# Original: calls, Lemmatized: call
# Original: incentives, Lemmatized: incentive
# Original: expenses, Lemmatized: expense
# Original: customers, Lemmatized: customer
# Original: violets, Lemmatized: violet
# Original: requirements, Lemmatized: requirement
# Original: costs, Lemmatized: cost
# Original: areas, Lemmatized: area
# Original: meetings, Lemmatized: meeting
# Original: qualities, Lemmatized: quality
# Original: indications, Lemmatized: indication
# Original: competitions, Lemmatized: competition
# Original: campaigns, Lemmatized: campaign
# Original: mountains, Lemmatized: mountain
# Original: awards, Lemmatized: award
# Original: aspirations, Lemmatized: aspiration
# Original: maths, Lemmatized: math
# Original: tools, Lemmatized: tool
# Original: applications, Lemmatized: application
# Original: details, Lemmatized: detail
# Original: solutions, Lemmatized: solution
# Original: enquiries, Lemmatized: enquiry
# Original: managers, Lemmatized: manager
# Original: leaders, Lemmatized: leader
# Original: acts, Lemmatized: act
# Original: workers, Lemmatized: worker
# Original: disclaimers, Lemmatized: disclaimer
# Original: surveyors, Lemmatized: surveyor
# Original: contracts, Lemmatized: contract
# Original: sales, Lemmatized: sale
# Original: tools, Lemmatized: tool

# %% [markdown]
# ### Saving outputs
# Save the count vector representation as per spectification.
# - vocab.txt

# %%
# Build a vocabulary of the cleaned job advertisement descriptions
vocabulary = {word: index for index, word in enumerate(sorted(set(all_words) - most_common_words))}

# Save the vocabulary to a text file
with open("vocab.txt", 'w', encoding='utf-8') as file:
    for word, index in sorted(vocabulary.items(), key=lambda x: x[1]):
        file.write(f"{word}:{index}\n")

# %% [markdown]
# ## Summary
#
# 1. Data Loading: The task starts with loading job advertisement data which includes data from 4 different job categories namely Accounting Finance, Engineering, Healthcare Nursing, and Sales where each category has the details of the job like Title, Webindex,	Company, and Description.
#
# 2. Text Preprocessing: The descriptions of job advertisements are preprocessed to make them suitable for text analysis. Common preprocessing steps include tokenization, lowercase conversion, and the removal of stopwords, punctuation, and short words.
#
# 3. Lemmatization: Lemmatization is applied to the tokenized words to reduce them to their base or dictionary form. This helps in standardizing words (e.g., "carries" to "carry") and can improve text analysis accuracy.
#
# 4. Word Frequency Analysis: The code computes word frequencies to understand the distribution of words in the job advertisements. This information can be useful for various natural language processing tasks.
#
# 5. Saving the files: Once the preprocessing is done i.e., sorting the words, removing 50 most common for words; the description of the job advertisements are stored in preprocessing_ads.csv with Webindex and Description of the jobs. The cleaned vocabulary dictionary is then saved to vocab.txt
